# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/MarwaQabeel/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students.git">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students
# Out:
# /content/drive/MyDrive/Colab Notebooks/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students

# %%
# !git clone https://github.com/MarwaQabeel/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students.git
# Out:
# Cloning into 'Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 4), reused 15 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 7.52 KiB | 855.00 KiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# 1. Configure GitHub user details
# !git config --global user.name MarwaQabeel
# !git config --global user.email mqabeel3@gatech.edu

# %%
# !git config --global credential.helper store

# %%
# !git add .

# %%
# !git commit -m "add data"
# Out:
# [main 029fde9] add data
#  2 files changed, 1 insertion(+), 2 deletions(-)
#  rewrite Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students (1).ipynb (67%)
#  delete mode 100644 Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students.ipynb

# %%
# !git config http.postBuffer 524288000  # Set to 500 MB

# %%
# !git rm --cached Data/embedding/glove.twitter.27B.100d.txt
# Out:
# fatal: pathspec 'Data/embedding/glove.twitter.27B.100d.txt' did not match any files

# %%
# Push the changes to the GitHub repository

# !git push https://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@github.com/MarwaQabeel/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students.git
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 803 bytes | 114.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/MarwaQabeel/Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students.git
#    a0bbee2..029fde9  main -> main

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !git lfs track "Data/embedding/glove.twitter.27B.100d.txt"
# !git lfs track "Data/embedding/glove.twitter.27B.100d.txt.pt"
# Out:
# Tracking "Data/embedding/glove.twitter.27B.100d.txt"
# Tracking "Data/embedding/glove.twitter.27B.100d.txt.pt"

# %%
# !git add .gitattributes
# !git add Data/embedding/glove.twitter.27B.100d.txt.pt
# !git add Data/embedding/glove.twitter.27B.100d.txt
# !git commit -m "Track large embedding files with Git LFS"
# Out:
# fatal: pathspec 'Data/embedding/glove.twitter.27B.100d.txt.pt' did not match any files
# fatal: pathspec 'Data/embedding/glove.twitter.27B.100d.txt' did not match any files
# fatal: cannot exec '.git/hooks/post-commit': Permission denied
# [main f423355] Track large embedding files with Git LFS
#  1 file changed, 2 insertions(+)
#  create mode 100644 .gitattributes

# %%
# !git rm --cached Data/embedding/glove.twitter.27B.100d.txt
# Out:
# fatal: pathspec 'Data/embedding/glove.twitter.27B.100d.txt' did not match any files

# %%
Optimizing-EDM-and-LA-to-Enhance-Equity-for-Underrepresented-Students
